# %%
import numpy as np

# %%
my_list = list(range(100000)) ## python list 0~-99999 gacha bo'lgan sonlar --> Normal
my_array = np.array(range(100000))  ## numpy array(massiv) ko'rinishda 0~99999 -->Vektorlashgan

# %%
#print(my_list)

# %%
#print(my_array)

# %%
# %time for _ in range(10): [x*2 for x in my_list] #Normal usuli
# Out:
# CPU times: user 48 ms, sys: 0 ns, total: 48 ms
# Wall time: 47.9 ms

# %%
# %time for _ in range(10): my_array*2 # Vektorlashgan usuli
# Out:
# CPU times: user 1.99 ms, sys: 112 µs, total: 2.1 ms
# Wall time: 2.87 ms

# %%
47.9/2.87
# Out:
# 16.689895470383274
