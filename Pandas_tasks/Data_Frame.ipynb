# %% [markdown]
# #Pandas kutubxonasidagi Data Frame ma'lumotlar tuzilmasi

# %%
import pandas as pd

# %%
data = {'Yili': [2021, 2020, 2019, 2018, 2017, 2016, 2015, 2010],
        'Aholi soni': [33.9, 33.5, 32.9, 32.5, 31.9, 31.4, 30.9, 28.5],
        "Temp": [1.54, 1.48, 1.56, 1.62, 1.65, 1.66, 1.64, 1.53]}

df = pd.DataFrame(data)

# %%
df
# Out:
#    Yili  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.62
# 4  2017        31.9  1.65
# 5  2016        31.4  1.66
# 6  2015        30.9  1.64
# 7  2010        28.5  1.53

# %%
df.head()
# Out:
#    Yili  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.62
# 4  2017        31.9  1.65

# %%
df.head(2)
# Out:
#    Yili  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48

# %%
df.shape
# Out:
# (8, 3)

# %%
df = pd.DataFrame(data, columns=['Yil', 'Temp', "Aholi soni"])

# %%
df.head()
# Out:
#    Yil  Temp  Aholi soni
# 0  NaN  1.54        33.9
# 1  NaN  1.48        33.5
# 2  NaN  1.56        32.9
# 3  NaN  1.62        32.5
# 4  NaN  1.65        31.9

# %%
df = pd.DataFrame(data, columns=['Yil', 'Temp', "Aholi soni", 'YAIM'], index=[20, 12, 25, 45, 65, 85, 99, 77])

# %%
df
# Out:
#     Yil  Temp  Aholi soni YAIM
# 20  NaN  1.54        33.9  NaN
# 12  NaN  1.48        33.5  NaN
# 25  NaN  1.56        32.9  NaN
# 45  NaN  1.62        32.5  NaN
# 65  NaN  1.65        31.9  NaN
# 85  NaN  1.66        31.4  NaN
# 99  NaN  1.64        30.9  NaN
# 77  NaN  1.53        28.5  NaN

# %%
aholi = df["Aholi soni"]

# %%
aholi
# Out:
# 20    33.9
# 12    33.5
# 25    32.9
# 45    32.5
# 65    31.9
# 85    31.4
# 99    30.9
# 77    28.5
# Name: Aholi soni, dtype: float64

# %%
type(aholi)
# Out:
# pandas.core.series.Series

# %%
df.Temp
# Out:
# 20    1.54
# 12    1.48
# 25    1.56
# 45    1.62
# 65    1.65
# 85    1.66
# 99    1.64
# 77    1.53
# Name: Temp, dtype: float64

# %%
df.YAIM = 0

# %%
df
# Out:
#     Yil  Temp  Aholi soni  YAIM
# 20  NaN  1.54        33.9     0
# 12  NaN  1.48        33.5     0
# 25  NaN  1.56        32.9     0
# 45  NaN  1.62        32.5     0
# 65  NaN  1.65        31.9     0
# 85  NaN  1.66        31.4     0
# 99  NaN  1.64        30.9     0
# 77  NaN  1.53        28.5     0

# %%
val = pd.Series([1800, 2500, 4500, 7898], index=[20, 12, 65, 77])
df.YAIM = val

# %%
df
# Out:
#     Yil  Temp  Aholi soni    YAIM
# 20  NaN  1.54        33.9  1800.0
# 12  NaN  1.48        33.5  2500.0
# 25  NaN  1.56        32.9     NaN
# 45  NaN  1.62        32.5     NaN
# 65  NaN  1.65        31.9  4500.0
# 85  NaN  1.66        31.4     NaN
# 99  NaN  1.64        30.9     NaN
# 77  NaN  1.53        28.5  7898.0

# %%
val2 = [1800, 2500, 1450, 5445, 4500, 8888, 7777, 7889]
df.YAIM = val2

# %%
df
# Out:
#     Yil  Temp  Aholi soni  YAIM
# 20  NaN  1.54        33.9  1800
# 12  NaN  1.48        33.5  2500
# 25  NaN  1.56        32.9  1450
# 45  NaN  1.62        32.5  5445
# 65  NaN  1.65        31.9  4500
# 85  NaN  1.66        31.4  8888
# 99  NaN  1.64        30.9  7777
# 77  NaN  1.53        28.5  7889

# %%
df['4000+'] = df.YAIM > 4000

# %%
df
# Out:
#     Yil  Temp  Aholi soni  YAIM  4000+
# 20  NaN  1.54        33.9  1800  False
# 12  NaN  1.48        33.5  2500  False
# 25  NaN  1.56        32.9  1450  False
# 45  NaN  1.62        32.5  5445   True
# 65  NaN  1.65        31.9  4500   True
# 85  NaN  1.66        31.4  8888   True
# 99  NaN  1.64        30.9  7777   True
# 77  NaN  1.53        28.5  7889   True

# %%
del df['4000+']

# %%
df
# Out:
#     Yil  Temp  Aholi soni  YAIM
# 20  NaN  1.54        33.9  1800
# 12  NaN  1.48        33.5  2500
# 25  NaN  1.56        32.9  1450
# 45  NaN  1.62        32.5  5445
# 65  NaN  1.65        31.9  4500
# 85  NaN  1.66        31.4  8888
# 99  NaN  1.64        30.9  7777
# 77  NaN  1.53        28.5  7889

# %%
data = {'Uzbekistan': {2021:33.9, 2020:33.5, 2019:32.9, 2018:32.5, 2017:31.9},
        'Kazakhstan': {2021:18.9, 2020:18.7, 2019:18.5, 2018:18.3, 2017:18.1, 2016:17.8}}
df2 = pd.DataFrame(data)

# %%
df2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
df2.index.name = 'Yil'

# %%
df2
# Out:
#       Uzbekistan  Kazakhstan
# Yil
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
df2 = pd.DataFrame(data, index=[2021, 2019, 2017])

# %%
df2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2019        32.9        18.5
# 2017        31.9        18.1

# %%
df2.T
# Out:
#             2021  2019  2017
# Uzbekistan  33.9  32.9  31.9
# Kazakhstan  18.9  18.5  18.1

# %%
array = df2.values

# %%
array
# Out:
# array([[33.9, 18.9],
#        [32.9, 18.5],
#        [31.9, 18.1]])

# %%
type(array)
# Out:
# numpy.ndarray

# %%
df2.index
# Out:
# Index([2021, 2019, 2017], dtype='int64')

# %%
df
# Out:
#     Yil  Temp  Aholi soni  YAIM
# 20  NaN  1.54        33.9  1800
# 12  NaN  1.48        33.5  2500
# 25  NaN  1.56        32.9  1450
# 45  NaN  1.62        32.5  5445
# 65  NaN  1.65        31.9  4500
# 85  NaN  1.66        31.4  8888
# 99  NaN  1.64        30.9  7777
# 77  NaN  1.53        28.5  7889

# %%
df.index
# Out:
# Index([20, 12, 25, 45, 65, 85, 99, 77], dtype='int64')

# %%
df.columns
# Out:
# Index(['Yil', 'Temp', 'Aholi soni', 'YAIM'], dtype='object')

# %%
indeks = df.columns

# %%
indeks
# Out:
# Index(['Yil', 'Temp', 'Aholi soni', 'YAIM'], dtype='object')

# %%
'Yil' in indeks
# Out:
# True

# %%
df2
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2019        32.9        18.5
# 2017        31.9        18.1

# %%
'Tajikistan' in df2.columns
# Out:
# False

# %%
2021 in df2.index
# Out:
# True

# %%
indeks
# Out:
# Index(['Yil', 'Temp', 'Aholi soni', 'YAIM'], dtype='object')

# %%
indeks[0]
# Out:
# 'Yil'

# %%
indeks[2:4]
# Out:
# Index(['Aholi soni', 'YAIM'], dtype='object')

# %%
data1 = {'Uzbekistan': {2021:33.9, 2020:33.5, 2019:32.9, 2018:32.5, 2017:31.9},
        'Kazakhstan': {2021:18.9, 2020:18.7, 2019:18.5, 2018:18.3, 2017:18.1, 2016:17.8}}
df = pd.DataFrame(data)

# %%
df
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
usernames = {"bahodir":"bshodir1234", "olim":"olimtoy", "maryam":"5444", "nodira":"4466"}
emails = {"bahodir":"bahodir@2001", "olim":"olim@mail.ru", "maryam":"maryam1234", "nodira":"nodira@666gmail.com"}

# %%
data = {'usernames': usernames, 'emails':emails}
df = pd.DataFrame(data)

# %%
df
# Out:
#            usernames               emails
# bahodir  bshodir1234         bahodir@2001
# olim         olimtoy         olim@mail.ru
# maryam          5444           maryam1234
# nodira          4466  nodira@666gmail.com

# %%
df.index
# Out:
# Index(['bahodir', 'olim', 'maryam', 'nodira'], dtype='object')

# %%
arr = ['bahodir', 'olim', 'maryam', 'nodira']

# %%
arr[1]
# Out:
# 'olim'

# %%
data2 = {'usernames': {'olim':'olimjonov21', "maryam":'maryam2020'},
         'emails':{'olim':'olimjonov21@gmail.ru', "maryam":'maryam2020@gmail.com'}}

# %%
df2 = pd.concat([df, pd.DataFrame(data2)])
df2
# Out:
#            usernames                emails
# bahodir  bshodir1234          bahodir@2001
# olim         olimtoy          olim@mail.ru
# maryam          5444            maryam1234
# nodira          4466   nodira@666gmail.com
# olim     olimjonov21  olimjonov21@gmail.ru
# maryam    maryam2020  maryam2020@gmail.com

# %%
newmind = pd.Index(['olim', 'soliha', 'jasmina', 'Muxsina'])
newmind.isin(df2.index)
# Out:
# array([ True, False, False, False])

# %%
df2.index.difference(newmind)
# Out:
# Index(['bahodir', 'maryam', 'nodira'], dtype='object')

# %%
newmind.difference(df2.index)
# Out:
# Index(['Muxsina', 'jasmina', 'soliha'], dtype='object')

# %% [markdown]
# #union()

# %%
df2.index.union(newmind)
# Out:
# Index(['Muxsina', 'bahodir', 'jasmina', 'maryam', 'maryam', 'nodira', 'olim',
#        'olim', 'soliha'],
#       dtype='object')

# %% [markdown]
# #delete()

# %%
df2.index.delete(0)
# Out:
# Index(['olim', 'maryam', 'nodira', 'olim', 'maryam'], dtype='object')

# %% [markdown]
# #drop()

# %%
newmind.drop('soliha')
# Out:
# Index(['olim', 'jasmina', 'Muxsina'], dtype='object')

# %%
newmind
# Out:
# Index(['olim', 'soliha', 'jasmina', 'Muxsina'], dtype='object')

# %%
df2.index
# Out:
# Index(['bahodir', 'olim', 'maryam', 'nodira', 'olim', 'maryam'], dtype='object')

# %% [markdown]
# .insert()

# %%
df2.index.insert(4, 'Suraya')
# Out:
# Index(['bahodir', 'olim', 'maryam', 'nodira', 'Suraya', 'olim', 'maryam'], dtype='object')

# %% [markdown]
# #.is_monotonic() va .is_unique()

# %%
df2.index.is_monotonic_decreasing
# Out:
# False

# %%
df2.index.is_unique
# Out:
# False

# %%
newmind
# Out:
# Index(['olim', 'soliha', 'jasmina', 'Muxsina'], dtype='object')

# %%
newmind.is_unique
# Out:
# True

# %% [markdown]
# #uniqu()

# %%
df2.index.unique() ## takrorlanmas elementlar
# Out:
# Index(['bahodir', 'olim', 'maryam', 'nodira'], dtype='object')
