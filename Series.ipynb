# %% [markdown]
# <a href="https://colab.research.google.com/github/Bahodir01I/Data_Science-darslarim/blob/main/Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Pandas kutubxonasi bu - aynan data science ga yo'naltirilib u ma'lumotlarga ishlov berish uchun ishlatiladi

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ##pandas ma'luomotlar tuzilmasida ikkita muhim malumot tuzilmasi bor ular : Series va dataframe

# %% [markdown]
# Series

# %%
from pandas import Series

# %%
obj = Series([4, 2, 6, 8, 6, 7.8])

# %%
type(obj)
# Out:
# pandas.core.series.Series

# %%
obj
# Out:
# 0    4.0
# 1    2.0
# 2    6.0
# 3    8.0
# 4    6.0
# 5    7.8
# dtype: float64

# %%
print(obj)
# Out:
# 0    4.0
# 1    2.0
# 2    6.0
# 3    8.0
# 4    6.0
# 5    7.8
# dtype: float64

# %%
obj.values
# Out:
# array([4. , 2. , 6. , 8. , 6. , 7.8])

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
obj[2]
# Out:
# np.float64(6.0)

# %%
obj2 = Series([2, 5, 6, 8, 9, 7, 3, 7], index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])

# %%
obj2['b']
# Out:
# np.int64(5)

# %%
obj2[['a', 'd', 'h', 'f']]
# Out:
# a    2
# d    8
# h    7
# f    7
# dtype: int64

# %%
obj2[['b', 'b', 'b', 'b']]
# Out:
# b    5
# b    5
# b    5
# b    5
# dtype: int64

# %%
obj2[obj2>4]
# Out:
# b    5
# c    6
# d    8
# e    9
# f    7
# h    7
# dtype: int64

# %%
obj2 * 2
# Out:
# a     4
# b    10
# c    12
# d    16
# e    18
# f    14
# g     6
# h    14
# dtype: int64

# %%
obj2
# Out:
# a    2
# b    5
# c    6
# d    8
# e    9
# f    7
# g    3
# h    7
# dtype: int64

# %%
np.exp(obj2)
# Out:
# a       7.389056
# b     148.413159
# c     403.428793
# d    2980.957987
# e    8103.083928
# f    1096.633158
# g      20.085537
# h    1096.633158
# dtype: float64

# %%
obj2['a']
# Out:
# np.int64(2)

# %%
obj2
# Out:
# a    2
# b    5
# c    6
# d    8
# e    9
# f    7
# g    3
# h    7
# dtype: int64

# %% [markdown]
# #pythonda yozilgan lug'atlarni osongina series malumotlar turiga o'tkazish mumkin

# %%
cars_dict = {'Malibu': 40000, 'Lacetti': 20000, 'Toyota': 45000, 'Mazda':52000, 'Honda': 38000}

# %%
type(cars_dict)
# Out:
# dict

# %%
cars1 = Series(cars_dict)

# %%
cars1
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     45000
# Mazda      52000
# Honda      38000
# dtype: int64

# %%
type(cars1)
# Out:
# pandas.core.series.Series

# %%
cars1 = Series({'Malibu': 40000, 'Lacetti': 20000, 'Toyota': 45000, 'Mazda':52000, 'Honda': 38000})

# %%
cars1
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     45000
# Mazda      52000
# Honda      38000
# dtype: int64

# %%
'Malibu' in cars1
# Out:
# True

# %%
'BMW' in cars1
# Out:
# False

# %%
cars1['Toyota']
# Out:
# np.int64(45000)

# %%
models = ['Honda', 'Mazda', 'Lacetti', 'Jagua', 'Malibu', 'Toyota', 'Hongi']

# %%
cars2 = Series(cars_dict, index=models)

# %%
cars_dict
# Out:
# {'Malibu': 40000,
#  'Lacetti': 20000,
#  'Toyota': 45000,
#  'Mazda': 52000,
#  'Honda': 38000}

# %%
cars2
# Out:
# Honda      38000.0
# Mazda      52000.0
# Lacetti    20000.0
# Jagua          NaN
# Malibu     40000.0
# Toyota     45000.0
# Hongi          NaN
# dtype: float64

# %%
cars2.isnull() ## bu qiymat null (mavjud emasligini) tekshirish uchun
# Out:
# Honda      False
# Mazda      False
# Lacetti    False
# Jagua       True
# Malibu     False
# Toyota     False
# Hongi       True
# dtype: bool

# %%
cars2.notnull() ## bu esa qiymat null emasligini (mavjudligini) tekshirish uchun ishlatiladi
# Out:
# Honda       True
# Mazda       True
# Lacetti     True
# Jagua      False
# Malibu      True
# Toyota      True
# Hongi      False
# dtype: bool

# %%
cars2
# Out:
# Honda      38000.0
# Mazda      52000.0
# Lacetti    20000.0
# Jagua          NaN
# Malibu     40000.0
# Toyota     45000.0
# Hongi          NaN
# dtype: float64

# %%
cars1
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     45000
# Mazda      52000
# Honda      38000
# dtype: int64

# %%
cars2 + cars1
# Out:
# Honda       76000.0
# Hongi           NaN
# Jagua           NaN
# Lacetti     40000.0
# Malibu      80000.0
# Mazda      104000.0
# Toyota      90000.0
# dtype: float64

# %%
cars2.name = 'Avtosalon'

# %%
cars2.index.name = 'Modellar'

# %%
cars2
# Out:
# Modellar
# Honda      38000.0
# Mazda      52000.0
# Lacetti    20000.0
# Jagua          NaN
# Malibu     40000.0
# Toyota     45000.0
# Hongi          NaN
# Name: Avtosalon, dtype: float64

# %% [markdown]
# ## `Series` obyektiga oid ba'zi parametrlar va metodlar

# %%
cars2
# Out:
# Modellar
# Honda      38000.0
# Mazda      52000.0
# Lacetti    20000.0
# Jagua          NaN
# Malibu     40000.0
# Toyota     45000.0
# Hongi          NaN
# Name: Avtosalon, dtype: float64

# %%
cars2.index # indexlar
# Out:
# Index(['Honda', 'Mazda', 'Lacetti', 'Jagua', 'Malibu', 'Toyota', 'Hongi'], dtype='object', name='Modellar')

# %%
cars2.values # qiymatlar
# Out:
# array([38000., 52000., 20000.,    nan, 40000., 45000.,    nan])

# %%
cars2.hasnans # nan qiymatlar borligini tekshiradi b/sa (True), aks holda (False)
# Out:
# True

# %%
cars2.dtype # qiymat ma'lumot turini bilish uchun
# Out:
# dtype('float64')

# %%
cars2.is_unique # bu qiymatlarni takrorlanmas ekanligini tekshiradi
# Out:
# False

# %%
cars2.shape #series hajmi
# Out:
# (7,)

# %%
cars2.size #series hajmi
# Out:
# 7

# %%
cars2.iloc[2] #malumotni indeks raqami bo'yicha murojat qilish
# Out:
# np.float64(20000.0)

# %%
cars2[-2]
# Out:
# /tmp/ipykernel_185/3051620245.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cars2[-2]
# np.float64(45000.0)

# %%
cars2['Lacetti'] # ma'lumotlarga indeks bo'yicha murojaat qilish
# Out:
# np.float64(20000.0)

# %%
cars2.loc['Mazda'] # ma'lumotlarga indeks bo'yicha murojaat qilish
# Out:
# np.float64(52000.0)

# %%
cars2.max() # max qiymat
# Out:
# 52000.0

# %%
cars2.min() # min qiymat
# Out:
# 20000.0

# %%
cars2.mean() # mean (o'rta) qiymatini topish
# Out:
# np.float64(39000.0)

# %%
cars1_dict = {'Malibu':'Gm moshinasi juda qulay', 'Lacetti':'Oldin chiqgan gm moshinasi', 'Toyota':'Yaponiyani mashhur mashinalaridan biri', 'Mazda':'Yangi moshina'} # bu lug'at

# %%
yangi = Series(cars1_dict)

# %%
yangi
# Out:
# Malibu                    Gm moshinasi juda qulay
# Lacetti                Oldin chiqgan gm moshinasi
# Toyota     Yaponiyani mashhur mashinalaridan biri
# Mazda                               Yangi moshina
# dtype: object

# %%
yangi.index
# Out:
# Index(['Malibu', 'Lacetti', 'Toyota', 'Mazda'], dtype='object')

# %%
yangi.values
# Out:
# array(['Gm moshinasi juda qulay', 'Oldin chiqgan gm moshinasi',
#        'Yaponiyani mashhur mashinalaridan biri', 'Yangi moshina'],
#       dtype=object)

# %%
yangi[2]
# Out:
# /tmp/ipykernel_185/2833842863.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   yangi[2]
# 'Yaponiyani mashhur mashinalaridan biri'

# %%
yangi['Mazda']
# Out:
# 'Yangi moshina'
